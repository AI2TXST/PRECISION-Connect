# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
pd.set_option('display.max_columns', 1000)

# %%
df = pd.read_csv("../texasCountySummariesOASIS.csv")
print(df.columns)
# Out:
# /tmp/ipykernel_551919/1671755169.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../texasCountySummariesOASIS.csv")
# Index(['County', 'Fips', 'geometry', 'Beneficiary_ID',
#        'Assessment_Effective_Date', 'Submitted_HIPPS_Code',
#        'Facility_Internal_ID', 'Age', 'Gender',
#        'American_Indian_or_Alaska_Native',
#        ...
#        'ACS_PCT_POV_BLACK', 'ACS_PCT_POV_HISPANIC', 'ACS_PCT_POV_MULTI',
#        'ACS_PCT_POV_NHPI', 'ACS_PCT_POV_OTHER', 'ACS_PCT_POV_WHITE',
#        'ACS_PCT_VET_POV_18_64', 'ACS_TOT_POP_POV', 'ICD_Section', 'ICD_Range'],
#       dtype='object', length=101)

# %%
df
# Out:
#            County   Fips                                           geometry  \
# 0       Ochiltree  48357  POLYGON ((-100.936058 36.499602, -100.918513 3...
# 1       Ochiltree  48357  POLYGON ((-100.936058 36.499602, -100.918513 3...
# 2       Ochiltree  48357  POLYGON ((-100.936058 36.499602, -100.918513 3...
# 3       Ochiltree  48357  POLYGON ((-100.936058 36.499602, -100.918513 3...
# 4       Ochiltree  48357  POLYGON ((-100.936058 36.499602, -100.918513 3...
# ...           ...    ...                                                ...
# 221952     Potter  48375  POLYGON ((-101.622941 35.183117, -102.167471 3...
# 221953     Potter  48375  POLYGON ((-101.622941 35.183117, -102.167471 3...
# 221954     Potter  48375  POLYGON ((-101.622941 35.183117, -102.167471 3...
# 221955     Potter  48375  POLYGON ((-101.622941 35.183117, -102.167471 3...
# 221956     Potter  48375  POLYGON ((-101.622941 35.183117, -102.167471 3...
#
# ...

# %%
full_cohort = df.copy()
diabetes_cohort = full_cohort[full_cohort['has_diabetes'] == 1]
hf_cohort = full_cohort[full_cohort['has_heart_failure'] == 1]
htn_cohort = full_cohort[full_cohort['has_hypertension'] == 1]

# %%
diabetes_cohort.to_csv('../cohorts/diabetes_v1.csv', index=False)
hf_cohort.to_csv('../cohorts/heartfailure_v1.csv', index=False)
htn_cohort.to_csv('../cohorts/hypertension_v1.csv', index=False)

# %%
diabetes_cohort
# Out:
#            County   Fips                                           geometry  \
# 8       Ochiltree  48357  POLYGON ((-100.936058 36.499602, -100.918513 3...
# 16      Ochiltree  48357  POLYGON ((-100.936058 36.499602, -100.918513 3...
# 20      Ochiltree  48357  POLYGON ((-100.936058 36.499602, -100.918513 3...
# 27      Ochiltree  48357  POLYGON ((-100.936058 36.499602, -100.918513 3...
# 31      Ochiltree  48357  POLYGON ((-100.936058 36.499602, -100.918513 3...
# ...           ...    ...                                                ...
# 221922     Potter  48375  POLYGON ((-101.622941 35.183117, -102.167471 3...
# 221923     Potter  48375  POLYGON ((-101.622941 35.183117, -102.167471 3...
# 221924     Potter  48375  POLYGON ((-101.622941 35.183117, -102.167471 3...
# 221935     Potter  48375  POLYGON ((-101.622941 35.183117, -102.167471 3...
# 221942     Potter  48375  POLYGON ((-101.622941 35.183117, -102.167471 3...
#
# ...

# %%
diabetes_cohort.columns
# Out:
# Index(['County', 'Fips', 'geometry', 'Beneficiary_ID',
#        'Assessment_Effective_Date', 'Submitted_HIPPS_Code',
#        'Facility_Internal_ID', 'Age', 'Gender',
#        'American_Indian_or_Alaska_Native',
#        ...
#        'ACS_PCT_POV_BLACK', 'ACS_PCT_POV_HISPANIC', 'ACS_PCT_POV_MULTI',
#        'ACS_PCT_POV_NHPI', 'ACS_PCT_POV_OTHER', 'ACS_PCT_POV_WHITE',
#        'ACS_PCT_VET_POV_18_64', 'ACS_TOT_POP_POV', 'ICD_Section', 'ICD_Range'],
#       dtype='object', length=101)
